# %% [markdown]
# ## Assingments for sunday_20022022

# %%
"""Task for today :
  dataset -   https://archive.ics.uci.edu/ml/datasets/Bag+of+Words
    
    q1 = try to find out a count of each and every word in a respective file return a list of tuple with word and its respective count 
       sample example -  [('sudh', 6 ) , ('kumar',3)]
    q2 = try to perform a reduce operation to get a count of all the word starting with same alphabet
        sample examle = [(a,56) , (b,34),...........]
    q3 = Try to filter out all the words from dataset . 
    
    .001.abstract = abstract
    =.002 = delete
    q4 = create a tuple set of all the records avaialble in all the five file and then store it in sqllite DB . 
    (aah,>=,354,fdsf,wer)
    
    Top 10 will be able to get kids neuron """

# %% [markdown]
# ### Q1 = try to find out a count of each and every word in a respective file return a list of tuple with word and,its respective count sample example -  [('sudh', 6 ) , ('kumar',3)]

# %%
# file name vocab.enron.txt
       
with open("./SQLITE_Class/vocab.enron.txt") as file_01:
    enron_file = file_01.read().split()
    enron_len = []
    print(len(enron_file))
    #print(nips_file)
    print(type(enron_file))
    for i in enron_file:
        enron_len.append(len(i))
        
enron_final = list(zip(enron_file, enron_len))
print(len(enron_final))
# Out:
# 28102
# <class 'list'>
# 28102

# %%
# file name vocab.kos.txt
       
with open("./SQLITE_Class/vocab.kos.txt") as file_01:
    kos_file = file_01.read().split()
    kos_len = []
    print(len(kos_file))
    #print(nips_file)
    print(type(kos_file))
    for i in kos_file:
        kos_len.append(len(i))
        
kos_final = list(zip(kos_file, kos_len))
print(len(kos_final))
# Out:
# 6906
# <class 'list'>
# 6906

# %%
# file name vocab.nips.txt
       
with open("./SQLITE_Class/vocab.nips.txt") as file_01:
    nips_file = file_01.read().split()
    nips_len = []
    print(len(nips_file))
    #print(nips_file)
    print(type(read_file))
    for i in nips_file:
        nips_len.append(len(i))
        
nips_final = list(zip(nips_file, nips_len))
print(len(nips_final))
# Out:
# 12419
# <class 'list'>
# 12419

# %%
# file name vocab.nytimes.txt
       
with open("./SQLITE_Class/vocab.nytimes.txt") as file_01:
    nytimes_file = file_01.read().split()
    nytimes_len = []
    print(len(nytimes_file))
    #print(nips_file)
    print(type(nytimes_file))
    for i in nytimes_file:
        nytimes_len.append(len(i))
        
nytimes_final = list(zip(nytimes_file, nytimes_len))
print(len(nytimes_final))
# Out:
# 102660
# <class 'list'>
# 102660

# %% [markdown]
# ### Q2= try to perform a reduce operation to get a count of all the word starting with same alphabet, sample examle = [(a,56) , (b,34),...........]

# %%
from functools import reduce 
from collections import Counter

# %%
# file name vocab.enron.txt
enron_file
enron_count = list((Counter(s[0] for s in enron_file)).items())
len(enron_count)
# Out:
# 26

# %%
# file name vocab.kos.txt
kos_file
kos_count = list((Counter(s[0] for s in kos_file)).items())
len(kos_count)
# Out:
# 25

# %%
# file name vocab.nips.txt
nips_file
nips_count = list((Counter(s[0] for s in nips_file)).items())
len(nips_count)
# Out:
# 26

# %%
# file name vocab.nytimes.txt
nytimes_file
nytimes_count = list((Counter(s[0] for s in nytimes_file)).items())
len(nytimes_count)
# Out:
# 26

# %% [markdown]
# ### Q3 = Try to filter out all the words from dataset . =.001.abstract = abstract  =.002 = delete

# %%
#with open("./SQLITE_Class/vocab.nips.txt") as file_01:
#with open("./SQLITE_Class/vocab.nytimes.txt") as file_01:
#with open("./SQLITE_Class/vocab.enron.txt") as file_01:
#with open("./SQLITE_Class/vocab.kos.txt") as file_01:

#with open("./SQLITE_Class/vocab.pubmed.txt") as file_pu: # Its not readable file

# %%
# file name vocab.enron.txt
# file name vocab.kos.txt
# file name vocab.nips.txt
# file name vocab.nytimes.txt

# file name vocab.pubmed.txt  is not readabl file

# %%
# alphanumetic and abstract operaton from file 
# file name vocab.enron.txt

enron_alnum = []
enron_abstract = []
print(len(enron_file))

for i in enron_file:
    if i.isalnum():
        enron_alnum.append(i)
    else:
        enron_abstract.append(i)
        

print(len(enron_alnum))
print(len(enron_abstract))
print(len(enron_alnum) +len(enron_abstract))
# Out:
# 28102
# 27946
# 156
# 28102

# %%
# file name vocab.kos.txt
# alphanumetic and abstract operaton from file 

kos_alnum = []
kos_abstract = []
print(len(kos_file))

for i in kos_file:
    if i.isalnum():
        kos_alnum.append(i)
    else:
        kos_abstract.append(i)
        

print(len(kos_alnum))
print(len(kos_abstract))
print(len(kos_alnum) +len(kos_abstract))
# Out:
# 6906
# 6904
# 2
# 6906

# %%
# file name vocab.nips.txt
# alphanumetic and abstract operaton from file 

nips_alnum = []
nips_abstract = []
print(len(nips_file))

for i in nips_file:
    if i.isalnum():
        nips_alnum.append(i)
    else:
        nips_abstract.append(i)
        

print(len(nips_alnum))
print(len(nips_abstract))
print(len(nips_alnum) +len(nips_abstract))
# Out:
# 12419
# 12415
# 4
# 12419

# %%
# file name vocab.nytimes.txt
# alphanumetic and abstract operaton from file 

nytimes_alnum = []
nytimes_abstract = []
print(len(nytimes_file))

for i in nytimes_file:
    if i.isalnum():
        nytimes_alnum.append(i)
    else:
        nytimes_abstract.append(i)
        

print(len(nytimes_alnum))
print(len(nytimes_abstract))
print(len(nytimes_alnum) +len(nytimes_abstract))
# Out:
# 102660
# 44442
# 58218
# 102660

# %% [markdown]
#  ### Q4 = create a tuple set of all the records avaialble in all the five file and then store it in sqllite DB . (aah,>=,354,fdsf,wer)

# %%
import sqlite3
# file name

#enron_file
#kos_file
#nips_file
#nytimes_file

# %%
db = sqlite3.connect("Assignments_file.db")
c = db.cursor()
c.execute("create table All_file_01(enron_file text, kos_file text, nips_file text, nytimes_file text)")

# %%
# Lets dump all tuple set of all files in sqlite3 table in created database

for i in final_tuple:    
    c.execute(f"insert into All_file_01 values('{i[0]}', '{i[1]}', '{i[2]}', '{i[3]}')")

# %%
d = c.execute("select * from All_file_01")
d.fetchall()
# Out:
# [('aaa', 'aarp', 'a2i', 'aah'),
#  ('aaas', 'abandon', 'aaa', 'aahed'),
#  ('aactive', 'abandoned', 'aaai', 'aaron'),
#  ('aadvantage', 'abandoning', 'aapo', 'aback'),
#  ('aaker', 'abb', 'aat', 'abacus'),
#  ('aap', 'abc', 'aazhang', 'abajo'),
#  ('aapg', 'abcs', 'abandonment', 'abalone'),
#  ('aaron', 'abdullah', 'abbott', 'abandon'),
#  ('aarp', 'ability', 'abbreviated', 'abandoned'),
#  ('aas', 'aboard', 'abcde', 'abandoning'),
#  ('aau', 'abortion', 'abe', 'abandonment'),
#  ('ab1890', 'abortions', 'abeles', 'abandono'),
#  ('ab1x', 'abraham', 'abi', 'abarnard'),
#  ('ab31x', 'abrams', 'abilistic', 'abashed'),
#  ('aba', 'abroad', 'abilities', 'abate'),
#  ('abacus', 'absence', 'ability', 'abated'),
#  ('abag', 'absent', 'abl', 'abatement'),
#  ('abalone', 'absentee', 'able', 'abating'),
#  ('abandon', 'absolute', 'ables', 'abbey'),
#  ('abandoned', 'absolutely', 'ablex', 'abbot'),
#  ('abandoning', 'abstain', 'ably', 'abbreviated'),
# ...

# %%
db.commit()
db.close()
